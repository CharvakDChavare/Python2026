# %% [markdown]
# Reading CSV

# %%
import pandas as pd
# Method 1
df = pd.read_csv(r'C:\Users\CHARVAK\OneDrive\Desktop\DataSets\iris2.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Method 2
import csv

with open(r'C:\Users\CHARVAK\OneDrive\Desktop\DataSets\iris2.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        print(row)
# Out:
# {'sepal_length': '5.1', 'sepal_width': '3.5', 'petal_length': '1.4', 'petal_width': '0.2', 'species': 'setosa'}
# {'sepal_length': '4.9', 'sepal_width': '3.0', 'petal_length': '1.4', 'petal_width': '0.2', 'species': 'setosa'}
# {'sepal_length': '4.7', 'sepal_width': '3.2', 'petal_length': '1.3', 'petal_width': '0.2', 'species': 'setosa'}
# {'sepal_length': '4.6', 'sepal_width': '3.1', 'petal_length': '1.5', 'petal_width': '0.2', 'species': 'setosa'}
# {'sepal_length': '5.0', 'sepal_width': '3.6', 'petal_length': '1.4', 'petal_width': '0.2', 'species': 'setosa'}
# {'sepal_length': '5.4', 'sepal_width': '3.9', 'petal_length': '1.7', 'petal_width': '0.4', 'species': 'setosa'}
# {'sepal_length': '4.6', 'sepal_width': '3.4', 'petal_length': '1.4', 'petal_width': '0.3', 'species': 'setosa'}
# {'sepal_length': '5.0', 'sepal_width': '3.4', 'petal_length': '1.5', 'petal_width': '0.2', 'species': 'setosa'}
# ...

# %% [markdown]
# Writing CSV

# %%
# Panda Method
df.to_csv(r'C:\Users\CHARVAK\OneDrive\Desktop\DataSets\iris2.csv', index= False)
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
# csv module method
with open(r'C:\Users\CHARVAK\OneDrive\Desktop\DataSets\iris2.csv', 'w', newline='') as csvfile:
    fieldname =[' ', 'sepal_length', 'sepal_width', 'petal_length', 'petal_width','species'] 
    writer = csv.DictWriter(csvfile, fieldnames=fieldname)
    writer.writeheader()
    writer.writerow({' ':149, 'sepal_length':5.9, 'sepal_width': 3.1, 'petal_length':5.2, 'petal_width':1.9, 'species':'virginica'})

# %% [markdown]
# Writing Json

# %% [markdown]
# Reading Parquet

# %%
import pandas as pd
import pyarrow.parquet as pq
# Method 1

df = pd.read_parquet(
    r'C:\Users\CHARVAK\OneDrive\Desktop\DataSets\titanic_p.parquet',
    engine="pyarrow"
)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#method 2
table = pq.read_table(r'C:\Users\CHARVAK\OneDrive\Desktop\DataSets\titanic_p.parquet')
df = table.to_pandas()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Write Parquet

# %%
#method 1
df.to_parquet(r'C:\Users\CHARVAK\OneDrive\Desktop\DataSets\titanic_p.parquet', index=False)
