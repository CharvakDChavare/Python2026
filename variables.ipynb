# %% [markdown]
# Variable

# %% [markdown]
# Creating variable

# %%
x = 12
y = "charvak"
print(x)
print(y)
# Out:
# 12
# charvak

# %% [markdown]
# Casting, Get the type,

# %% [markdown]
# a = str(12)
# b = int(12)
# c = float(12)
# print(a)
# print(b)
# print(c)
# print(type(a))
# print(type(b))
# print(type(c))

# %% [markdown]
# Case-Sensitive

# %%
a = 12
A ="Charvak"
print(A)
print(a)
# A will not overwrite with a
# Out:
# Charvak
# 12

# %% [markdown]
# Variable Name:
#
# Rules for Python variables:
#
# A variable name must start with a letter or the underscore character
# A variable name cannot start with a number
# A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# Variable names are case-sensitive (age, Age and AGE are three different variables)
# A variable name cannot be any of the Python keywords.

# %% [markdown]
# Variables - Assign Multiple Values

# %%
x, y, z = "Charvak", "Dharamraj", "Chavare"
print(x)
print(y)
print(z)
# Out:
# Charvak
# Dharamraj
# Chavare

# %% [markdown]
# One Value to Multiple Variables

# %%
x = y = z = "Manav"
print(x)
print(y)
print(z)
# Out:
# Manav
# Manav
# Manav

# %% [markdown]
# Unpack a Collection

# %%
full_name = ["charvak", "Dharamraj", "chavare"]

x , y , z = full_name
print(x)
print(y)
print(z)
# Out:
# charvak
# Dharamraj
# chavare

# %% [markdown]
# You can also use the + operator to output multiple variables:

# %%
print(x + y + z)
# Out:
# charvakDharamrajchavare

# %% [markdown]
# Global Variables

# %%
x = "Charvak" # Global Variables

def myfunct():
    print("my self is " + x)

myfunct()
# Out:
# my self is Charvak

# %% [markdown]
# The global Keyword

# %%
def myfunc():
    global x
    x = "charvak"
    print(" I'am " + x)
myfunc()

print("my self is" + x)
# Out:
#  I'am charvak
# my self ischarvak
